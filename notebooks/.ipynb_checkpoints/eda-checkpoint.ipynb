# %%
import streamlit as st
import pandas as pd
import requests
import numpy as np
import yfinance as yf

# %% [markdown]
# First lets get the balance sheets and cash flow statements
# We are starting from January 2022, which is the furthest back for several DAOs w/o governance tokens.  We are starting w/o governance tokens because the rebalancing logic for those tokens is unique and will require adjustment to mvo/rdl.
#
# We will start with
# - CityDAO
# - Developer DAO
# - Lobster DAO
# - gmDAO
# - RugDAO

# %% [markdown]
# Three Month Tbill as risk free rate for sharpe ratio calc

# %%
tbill_path = '../data/3_month_t_bill.csv'

# %%
tbill_df = pd.read_csv(tbill_path)
tbill_df.tail()
# Out:
#           DATE  TB3MS
# 48  2023-11-01   5.27
# 49  2023-12-01   5.24
# 50  2024-01-01   5.22
# 51  2024-02-01   5.24
# 52  2024-03-01   5.24

# %%
tbill_df['DATE'] = pd.to_datetime(tbill_df['DATE'])
tbill_df.set_index('DATE', inplace=True)
tbill_daily = tbill_df.resample('D').ffill()
tbill_daily.tail()
# Out:
#             TB3MS
# DATE
# 2024-02-26   5.24
# 2024-02-27   5.24
# 2024-02-28   5.24
# 2024-02-29   5.24
# 2024-03-01   5.24

# %% [markdown]
# City DAO BS, Treasury Metrics

# %%
citydao_bs_path = '../data/citydao_bs.csv'

# %%
citydao_bs_df = pd.read_csv(citydao_bs_path)

# %%
citydao_bs_df.dropna(inplace=True)
citydao_bs_df.head()
# Out:
#                        DAY SYMBOL  DAILY_PRICE  FILLED_BALANCE  \
# 0  2021-08-10 00:00:00.000   USDC         1.00            0.00
# 1  2021-08-10 00:00:00.000  BACON         0.00            0.00
# 2  2021-08-10 00:00:00.000   WETH     3,175.67            0.00
# 3  2021-08-10 00:00:00.000    MTV         0.00            0.00
# 4  2021-08-10 00:00:00.000  TOKEN         0.00            0.00
#
#    TOTAL_VALUE_IN_USD  TOTAL_USD_IN_TREASURY  COMPOSITION
# 0                0.00              17,783.75         0.00
# 1                0.00              17,783.75         0.00
# 2                0.00              17,783.75         0.00
# 3                0.00              17,783.75         0.00
# 4                0.00              17,783.75         0.00

# %%
citydao_bs_df['DAY'] = pd.to_datetime(citydao_bs_df['DAY'], errors='coerce')
citydao_bs_df.set_index('DAY', inplace=True)

# %%
citydao_bs_df
# Out:
#            SYMBOL  DAILY_PRICE  FILLED_BALANCE  TOTAL_VALUE_IN_USD  \
# DAY
# 2021-08-10   USDC         1.00            0.00                0.00
# 2021-08-10  BACON         0.00            0.00                0.00
# 2021-08-10   WETH     3,175.67            0.00                0.00
# 2021-08-10    MTV         0.00            0.00                0.00
# 2021-08-10  TOKEN         0.00            0.00                0.00
# ...           ...          ...             ...                 ...
# 2024-04-05    MTV         0.00        1,000.00                1.87
# 2024-04-05   WETH     3,325.29          656.67        2,183,607.48
# 2024-04-05    ETH     3,325.29           12.65           42,061.31
# 2024-04-05   USDC         1.00      548,592.56          548,480.65
# 2024-04-05  TOKEN         0.15        3,561.63              539.87
#
#             TOTAL_USD_IN_TREASURY  COMPOSITION
# DAY
# 2021-08-10              17,783.75         0.00
# 2021-08-10              17,783.75         0.00
# 2021-08-10              17,783.75         0.00
# 2021-08-10              17,783.75         0.00
# 2021-08-10              17,783.75         0.00
# ...                           ...          ...
# 2024-04-05           2,774,695.36         0.00
# 2024-04-05           2,774,695.36         0.79
# 2024-04-05           2,774,695.36         0.02
# 2024-04-05           2,774,695.36         0.20
# 2024-04-05           2,774,695.36         0.00
#
# [5820 rows x 6 columns]

# %%
pivot_daily_price = pd.pivot_table(citydao_bs_df, values='DAILY_PRICE', index='DAY', columns='SYMBOL')

# You can do the same for the other features
pivot_total_filled_balance = pd.pivot_table(citydao_bs_df, values='FILLED_BALANCE', index='DAY', columns='SYMBOL')
pivot_total_value_in_usd = pd.pivot_table(citydao_bs_df, values='TOTAL_VALUE_IN_USD', index='DAY', columns='SYMBOL')
pivot_comp = pd.pivot_table(citydao_bs_df, values='COMPOSITION', index='DAY', columns='SYMBOL')
# If you want to combine these pivoted tables into one DataFrame with multi-level columns, you can use pd.concat
pivot_combined = pd.concat([pivot_daily_price, pivot_total_filled_balance, pivot_total_value_in_usd,pivot_comp], axis=1, keys=['DAILY_PRICE', 'FILLED_BALANCE', 'TOTAL_VALUE_IN_USD', 'COMPOSITION'])

# Show the combined pivoted DataFrame
pivot_combined.tail()
# Out:
#            DAILY_PRICE                                   FILLED_BALANCE        \
# SYMBOL           BACON      ETH  MTV TOKEN USDC     WETH          BACON   ETH
# DAY
# 2024-04-01        0.00 3,508.17 0.00  0.16 1.00 3,508.17       4,967.09 12.65
# 2024-04-02        0.00 3,289.01 0.00  0.15 1.00 3,289.01       4,967.09 12.65
# 2024-04-03        0.00 3,317.81 0.00  0.14 1.00 3,317.81       4,967.09 12.65
# 2024-04-04        0.00 3,325.29 0.00  0.15 1.00 3,325.29       4,967.09 12.65
# 2024-04-05        0.00 3,325.29 0.00  0.15 1.00 3,325.29       4,967.09 12.65
#
#                               ... TOTAL_VALUE_IN_USD                    \
# SYMBOL          MTV    TOKEN  ...                MTV  TOKEN       USDC
# DAY                           ...
# 2024-04-01 1,000.00 3,561.63  ...               1.92 581.32 559,062.93
# 2024-04-02 1,000.00 3,561.63  ...               1.79 533.07 547,734.02
# 2024-04-03 1,000.00 3,561.63  ...               1.77 513.56 548,392.33
# 2024-04-04 1,000.00 3,561.63  ...               1.87 539.87 548,480.65
# 2024-04-05 1,000.00 3,561.63  ...               1.87 539.87 548,480.65
#
#                         COMPOSITION
# SYMBOL             WETH       BACON  ETH  MTV TOKEN USDC WETH
# DAY
# 2024-04-01 2,303,698.70        0.00 0.02 0.00  0.00 0.19 0.79
# 2024-04-02 2,159,783.61        0.00 0.02 0.00  0.00 0.20 0.79
# 2024-04-03 2,178,695.61        0.00 0.02 0.00  0.00 0.20 0.79
# 2024-04-04 2,183,607.48        0.00 0.02 0.00  0.00 0.20 0.79
# 2024-04-05 2,183,607.48        0.00 0.02 0.00  0.00 0.20 0.79
#
# [5 rows x 24 columns]

# %%
citydao_treasury_index_path = '../data/citydao_treasury_index.csv'

# %%
citydao_index = pd.read_csv(citydao_treasury_index_path)
citydao_index.head()
# Out:
#                        DAY  TREASURY_RETURN
# 0  2022-02-01 00:00:00.000           100.00
# 1  2022-02-02 00:00:00.000            96.13
# 2  2022-02-03 00:00:00.000            95.74
# 3  2022-02-04 00:00:00.000           106.14
# 4  2022-02-05 00:00:00.000           107.27

# %%
citydao_index['DAY'] = pd.to_datetime(citydao_index['DAY'], errors='coerce')
citydao_index.set_index('DAY', inplace=True)
citydao_index.dropna(inplace=True)

# %%
citydao_rolling_metrics_path = '../data/citydao_rolling_metrics.csv'

# %%
citydao_rolling_metrics = pd.read_csv(citydao_rolling_metrics_path)

# %%
citydao_rolling_metrics.tail()
# Out:
#                          DAY  CUM_ROLLING_AVG_DAILY_RETURN  \
# 792  2024-04-02 00:00:00.000                          0.00
# 793  2024-04-03 00:00:00.000                          0.00
# 794  2024-04-04 00:00:00.000                          0.00
# 795  2024-04-05 00:00:00.000                          0.00
# 796                        ﻿                           NaN
#
#      CUM_ROLLING_STDDEV_DAILY_RETURN  ROLLING_AVG_30D  ROLLING_STDDEV_30D  \
# 792                             0.03            -0.00                0.03
# 793                             0.03            -0.00                0.03
# 794                             0.03            -0.00                0.03
# 795                             0.03            -0.00                0.03
# 796                              NaN              NaN                 NaN
#
#      ROLLING_AVG_90D  ROLLING_STDDEV_90D
# 792             0.00                0.02
# 793             0.00                0.02
# 794             0.00                0.02
# 795             0.00                0.02
# 796              NaN                 NaN

# %%
citydao_rolling_metrics['DAY'] = pd.to_datetime(citydao_rolling_metrics['DAY'], errors='coerce')
citydao_rolling_metrics.set_index('DAY', inplace=True)

# %%
citydao_rolling_metrics = citydao_rolling_metrics.dropna()

# %%
merged_df = citydao_rolling_metrics.merge(tbill_daily, left_index=True, right_index=True, how='left')

# %%
merged_df['TB3MS'].ffill(inplace=True)

# %%
merged_df['TB3MS']
# Out:
# DAY
# 2022-02-01   0.33
# 2022-02-02   0.33
# 2022-02-03   0.33
# 2022-02-04   0.33
# 2022-02-05   0.33
#              ...
# 2024-04-01   5.24
# 2024-04-02   5.24
# 2024-04-03   5.24
# 2024-04-04   5.24
# 2024-04-05   5.24
# Name: TB3MS, Length: 795, dtype: float64

# %%
merged_df['TB3MS'] = merged_df['TB3MS'].astype(float) / 100

# %%
merged_df['TB3MS'] = merged_df['TB3MS'].apply(lambda x: f"{x:.4f}")

# %%
merged_df['TB3MS'] = merged_df['TB3MS'].astype(float)

# %%
merged_df['TB3MS']
# Out:
# DAY
# 2022-02-01   0.00
# 2022-02-02   0.00
# 2022-02-03   0.00
# 2022-02-04   0.00
# 2022-02-05   0.00
#              ...
# 2024-04-01   0.05
# 2024-04-02   0.05
# 2024-04-03   0.05
# 2024-04-04   0.05
# 2024-04-05   0.05
# Name: TB3MS, Length: 795, dtype: float64

# %%
merged_df_filtered = merged_df[merged_df.index <= '2024-04-01']

# %%
merged_df_filtered.plot()
# Out:
# <Axes: xlabel='DAY'>

# %%
merged_df_filtered
# Out:
#             CUM_ROLLING_AVG_DAILY_RETURN  CUM_ROLLING_STDDEV_DAILY_RETURN  \
# DAY
# 2022-02-01                          0.02                             0.03
# 2022-02-02                         -0.00                             0.04
# 2022-02-03                         -0.00                             0.03
# 2022-02-04                          0.02                             0.06
# 2022-02-05                          0.02                             0.05
# ...                                  ...                              ...
# 2024-03-28                          0.00                             0.03
# 2024-03-29                          0.00                             0.03
# 2024-03-30                          0.00                             0.03
# 2024-03-31                          0.00                             0.03
# 2024-04-01                          0.00                             0.03
#
#             ROLLING_AVG_30D  ROLLING_STDDEV_30D  ROLLING_AVG_90D  \
# DAY
# 2022-02-01             0.02                0.03             0.02
# 2022-02-02            -0.00                0.04            -0.00
# 2022-02-03            -0.00                0.03            -0.00
# 2022-02-04             0.02                0.06             0.02
# 2022-02-05             0.02                0.05             0.02
# ...                     ...                 ...              ...
# 2024-03-28             0.00                0.03             0.00
# 2024-03-29             0.00                0.03             0.00
# 2024-03-30             0.00                0.03             0.00
# 2024-03-31             0.00                0.03             0.00
# 2024-04-01             0.00                0.03             0.00
#
#             ROLLING_STDDEV_90D  TB3MS
# DAY
# 2022-02-01                0.03   0.00
# 2022-02-02                0.04   0.00
# 2022-02-03                0.03   0.00
# 2022-02-04                0.06   0.00
# 2022-02-05                0.05   0.00
# ...                        ...    ...
# 2024-03-28                0.02   0.05
# 2024-03-29                0.02   0.05
# 2024-03-30                0.02   0.05
# 2024-03-31                0.02   0.05
# 2024-04-01                0.02   0.05
#
# [791 rows x 7 columns]

# %%
merged_df_filtered.tail()
# Out:
#             CUM_ROLLING_AVG_DAILY_RETURN  CUM_ROLLING_STDDEV_DAILY_RETURN  \
# DAY
# 2024-03-28                          0.00                             0.03
# 2024-03-29                          0.00                             0.03
# 2024-03-30                          0.00                             0.03
# 2024-03-31                          0.00                             0.03
# 2024-04-01                          0.00                             0.03
#
#             ROLLING_AVG_30D  ROLLING_STDDEV_30D  ROLLING_AVG_90D  \
# DAY
# 2024-03-28             0.00                0.03             0.00
# 2024-03-29             0.00                0.03             0.00
# 2024-03-30             0.00                0.03             0.00
# 2024-03-31             0.00                0.03             0.00
# 2024-04-01             0.00                0.03             0.00
#
#             ROLLING_STDDEV_90D  TB3MS
# DAY
# 2024-03-28                0.02   0.05
# 2024-03-29                0.02   0.05
# 2024-03-30                0.02   0.05
# 2024-03-31                0.02   0.05
# 2024-04-01                0.02   0.05

# %%
daily_rf_rate = merged_df_filtered['TB3MS']

# Annualize the standard deviations (assuming 252 trading days in a year)
annualized_stddev_cum = merged_df_filtered['CUM_ROLLING_STDDEV_DAILY_RETURN'] * (365**0.5)
annualized_stddev_30d = merged_df_filtered['ROLLING_STDDEV_30D'] * (365**0.5)
annualized_stddev_90d = merged_df_filtered['ROLLING_STDDEV_90D'] * (365**0.5)

# Calculate Sharpe Ratios for each period
merged_df_filtered['SHARPE_RATIO_CUM'] = (merged_df_filtered['CUM_ROLLING_AVG_DAILY_RETURN'] - daily_rf_rate) / annualized_stddev_cum
merged_df_filtered['SHARPE_RATIO_30D'] = (merged_df_filtered['ROLLING_AVG_30D'] - daily_rf_rate) / annualized_stddev_30d
merged_df_filtered['SHARPE_RATIO_90D'] = (merged_df_filtered['ROLLING_AVG_90D'] - daily_rf_rate) / annualized_stddev_90d

# View the resulting DataFrame
merged_df_filtered[['SHARPE_RATIO_CUM', 'SHARPE_RATIO_30D', 'SHARPE_RATIO_90D']].tail()
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_48512\3100333493.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_filtered['SHARPE_RATIO_CUM'] = (merged_df_filtered['CUM_ROLLING_AVG_DAILY_RETURN'] - daily_rf_rate) / annualized_stddev_cum
# C:\Users\brand\AppData\Local\Temp\ipykernel_48512\3100333493.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_filtered['SHARPE_RATIO_30D'] = (merged_df_filtered['ROLLING_AVG_30D'] - daily_rf_rate) / annualized_stddev_30d
# C:\Users\brand\AppData\Local\Temp\ipykernel_48512\3100333493.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_filtered['SHARPE_RATIO_90D'] = (merged_df_filtered['ROLLING_AVG_90D'] - daily_rf_rate) / annualized_stddev_90d
#             SHARPE_RATIO_CUM  SHARPE_RATIO_30D  SHARPE_RATIO_90D
# DAY
# 2024-03-28             -0.11             -0.08             -0.11
# 2024-03-29             -0.11             -0.08             -0.11
# 2024-03-30             -0.11             -0.08             -0.11
# 2024-03-31             -0.11             -0.08             -0.11
# 2024-04-01             -0.11             -0.08             -0.11

# %%
merged_df_filtered[['SHARPE_RATIO_CUM', 'SHARPE_RATIO_30D', 'SHARPE_RATIO_90D']].plot()
# Out:
# <Axes: xlabel='DAY'>

# %%
merged_df_filtered[['SHARPE_RATIO_CUM', 'SHARPE_RATIO_30D', 'SHARPE_RATIO_90D']].plot()
# Out:
# <Axes: xlabel='DAY'>

# %%
pivot_combined.columns = ['_'.join(col).strip() for col in pivot_combined.columns.values]

# %%
pivot_combined.columns
# Out:
# Index(['DAILY_PRICE_BACON', 'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV',
#        'DAILY_PRICE_TOKEN', 'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH',
#        'FILLED_BALANCE_BACON', 'FILLED_BALANCE_ETH', 'FILLED_BALANCE_MTV',
#        'FILLED_BALANCE_TOKEN', 'FILLED_BALANCE_USDC', 'FILLED_BALANCE_WETH',
#        'TOTAL_VALUE_IN_USD_BACON', 'TOTAL_VALUE_IN_USD_ETH',
#        'TOTAL_VALUE_IN_USD_MTV', 'TOTAL_VALUE_IN_USD_TOKEN',
#        'TOTAL_VALUE_IN_USD_USDC', 'TOTAL_VALUE_IN_USD_WETH',
#        'COMPOSITION_BACON', 'COMPOSITION_ETH', 'COMPOSITION_MTV',
#        'COMPOSITION_TOKEN', 'COMPOSITION_USDC', 'COMPOSITION_WETH'],
#       dtype='object')

# %%
pivot_combined['FILLED_BALANCE_BACON'].describe()
# Out:
# count     970.00
# mean    4,577.92
# std     1,335.46
# min         0.00
# 25%     4,967.09
# 50%     4,967.09
# 75%     4,967.09
# max     4,967.09
# Name: FILLED_BALANCE_BACON, dtype: float64

# %%
citydao_metrics = merged_df_filtered.merge(citydao_index, left_index=True, right_index=True)

# %%
citydao_metrics
# Out:
#             CUM_ROLLING_AVG_DAILY_RETURN  CUM_ROLLING_STDDEV_DAILY_RETURN  \
# DAY
# 2022-02-01                          0.02                             0.03
# 2022-02-02                         -0.00                             0.04
# 2022-02-03                         -0.00                             0.03
# 2022-02-04                          0.02                             0.06
# 2022-02-05                          0.02                             0.05
# ...                                  ...                              ...
# 2024-03-28                          0.00                             0.03
# 2024-03-29                          0.00                             0.03
# 2024-03-30                          0.00                             0.03
# 2024-03-31                          0.00                             0.03
# 2024-04-01                          0.00                             0.03
#
#             ROLLING_AVG_30D  ROLLING_STDDEV_30D  ROLLING_AVG_90D  \
# DAY
# 2022-02-01             0.02                0.03             0.02
# 2022-02-02            -0.00                0.04            -0.00
# 2022-02-03            -0.00                0.03            -0.00
# 2022-02-04             0.02                0.06             0.02
# 2022-02-05             0.02                0.05             0.02
# ...                     ...                 ...              ...
# 2024-03-28             0.00                0.03             0.00
# 2024-03-29             0.00                0.03             0.00
# 2024-03-30             0.00                0.03             0.00
# 2024-03-31             0.00                0.03             0.00
# 2024-04-01             0.00                0.03             0.00
#
#             ROLLING_STDDEV_90D  TB3MS  SHARPE_RATIO_CUM  SHARPE_RATIO_30D  \
# DAY
# 2022-02-01                0.03   0.00              0.03              0.03
# 2022-02-02                0.04   0.00             -0.01             -0.01
# 2022-02-03                0.03   0.00             -0.01             -0.01
# 2022-02-04                0.06   0.00              0.02              0.02
# 2022-02-05                0.05   0.00              0.02              0.02
# ...                        ...    ...               ...               ...
# 2024-03-28                0.02   0.05             -0.11             -0.08
# 2024-03-29                0.02   0.05             -0.11             -0.08
# 2024-03-30                0.02   0.05             -0.11             -0.08
# 2024-03-31                0.02   0.05             -0.11             -0.08
# 2024-04-01                0.02   0.05             -0.11             -0.08
#
#             SHARPE_RATIO_90D  TREASURY_RETURN
# DAY
# 2022-02-01              0.03           100.00
# 2022-02-02             -0.01            96.13
# 2022-02-03             -0.01            95.74
# 2022-02-04              0.02           106.14
# 2022-02-05              0.02           107.27
# ...                      ...              ...
# 2024-03-28             -0.11           108.15
# 2024-03-29             -0.11           106.84
# 2024-03-30             -0.11           106.49
# 2024-03-31             -0.11           109.85
# 2024-04-01             -0.11           106.59
#
# [791 rows x 11 columns]

# %%
citydao_df = pd.merge(pivot_combined.reset_index(), citydao_metrics.reset_index(), on='DAY', how='inner')

# %%
citydao_df.columns
# Out:
# Index(['DAY', 'DAILY_PRICE_BACON', 'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV',
#        'DAILY_PRICE_TOKEN', 'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH',
#        'FILLED_BALANCE_BACON', 'FILLED_BALANCE_ETH', 'FILLED_BALANCE_MTV',
#        'FILLED_BALANCE_TOKEN', 'FILLED_BALANCE_USDC', 'FILLED_BALANCE_WETH',
#        'TOTAL_VALUE_IN_USD_BACON', 'TOTAL_VALUE_IN_USD_ETH',
#        'TOTAL_VALUE_IN_USD_MTV', 'TOTAL_VALUE_IN_USD_TOKEN',
#        'TOTAL_VALUE_IN_USD_USDC', 'TOTAL_VALUE_IN_USD_WETH',
#        'COMPOSITION_BACON', 'COMPOSITION_ETH', 'COMPOSITION_MTV',
#        'COMPOSITION_TOKEN', 'COMPOSITION_USDC', 'COMPOSITION_WETH',
#        'CUM_ROLLING_AVG_DAILY_RETURN', 'CUM_ROLLING_STDDEV_DAILY_RETURN',
#        'ROLLING_AVG_30D', 'ROLLING_STDDEV_30D', 'ROLLING_AVG_90D',
#        'ROLLING_STDDEV_90D', 'TB3MS', 'SHARPE_RATIO_CUM', 'SHARPE_RATIO_30D',
#        'SHARPE_RATIO_90D', 'TREASURY_RETURN'],
#       dtype='object')

# %%
citydao_df.columns = [f'citydao_treasury_{col}' if col not in ['DAY','TB3MS'] and not col.startswith('DAILY_PRICE_') else col for col in citydao_df.columns]

# %%
citydao_df.columns
# Out:
# Index(['DAY', 'DAILY_PRICE_BACON', 'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV',
#        'DAILY_PRICE_TOKEN', 'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH',
#        'citydao_treasury_FILLED_BALANCE_BACON',
#        'citydao_treasury_FILLED_BALANCE_ETH',
#        'citydao_treasury_FILLED_BALANCE_MTV',
#        'citydao_treasury_FILLED_BALANCE_TOKEN',
#        'citydao_treasury_FILLED_BALANCE_USDC',
#        'citydao_treasury_FILLED_BALANCE_WETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_BACON',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_ETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_MTV',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_USDC',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_WETH',
#        'citydao_treasury_COMPOSITION_BACON',
#        'citydao_treasury_COMPOSITION_ETH', 'citydao_treasury_COMPOSITION_MTV',
#        'citydao_treasury_COMPOSITION_TOKEN',
#        'citydao_treasury_COMPOSITION_USDC',
#        'citydao_treasury_COMPOSITION_WETH',
#        'citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN',
#        'citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN',
#        'citydao_treasury_ROLLING_AVG_30D',
#        'citydao_treasury_ROLLING_STDDEV_30D',
#        'citydao_treasury_ROLLING_AVG_90D',
#        'citydao_treasury_ROLLING_STDDEV_90D', 'TB3MS',
#        'citydao_treasury_SHARPE_RATIO_CUM',
#        'citydao_treasury_SHARPE_RATIO_30D',
#        'citydao_treasury_SHARPE_RATIO_90D',
#        'citydao_treasury_TREASURY_RETURN'],
#       dtype='object')

# %%
citydao_cf_path = '../data/citydao_cf.csv'

# %%
citydao_cf = pd.read_csv(citydao_cf_path)

# %%
citydao_cf.dropna(inplace=True)
citydao_cf
# Out:
#                       MONTH        INFLOW       OUTFLOW  NET_CASH_FLOW
# 0   2024-05-01 00:00:00.000          0.00          0.00           0.00
# 1   2024-04-01 00:00:00.000          0.03     -1,503.02      -1,502.99
# 2   2024-03-01 00:00:00.000        149.52   -387,241.51    -387,091.99
# 3   2024-02-01 00:00:00.000        236.74     -4,131.31      -3,894.57
# 4   2024-01-01 00:00:00.000        166.26    -20,628.66     -20,462.40
# 5   2023-12-01 00:00:00.000        275.96     -6,027.33      -5,751.37
# 6   2023-11-01 00:00:00.000        232.06        -70.52         161.54
# 7   2023-10-01 00:00:00.000         56.15    -12,034.39     -11,978.24
# 8   2023-09-01 00:00:00.000     27,972.02     -1,614.21      26,357.82
# 9   2023-08-01 00:00:00.000        105.24     -9,024.91      -8,919.67
# 10  2023-07-01 00:00:00.000         83.45     -1,560.16      -1,476.70
# 11  2023-06-01 00:00:00.000         13.19     -7,293.96      -7,280.77
# 12  2023-05-01 00:00:00.000         65.54     -9,510.93      -9,445.39
# 13  2023-04-01 00:00:00.000        189.24     -1,651.02      -1,461.78
# 14  2023-03-01 00:00:00.000     18,122.97    -83,193.00     -65,070.03
# 15  2023-02-01 00:00:00.000      1,342.22    -78,509.12     -77,166.90
# 16  2023-01-01 00:00:00.000      2,912.85    -48,900.00     -45,987.15
# 17  2022-12-01 00:00:00.000      3,810.05     -7,060.09      -3,250.04
# 18  2022-11-01 00:00:00.000    592,374.03   -507,629.07      84,744.96
# 19  2022-10-01 00:00:00.000      1,158.15   -110,698.50    -109,540.35
# 20  2022-09-01 00:00:00.000      1,198.16   -377,805.00    -376,606.84
# 21  2022-08-01 00:00:00.000    356,940.66   -203,003.62     153,937.05
# 22  2022-07-01 00:00:00.000    781,943.53   -854,404.14     -72,460.61
# 23  2022-06-01 00:00:00.000    373,010.41 -2,633,917.81  -2,260,907.40
# 24  2022-05-01 00:00:00.000    300,569.52   -172,743.96     127,825.56
# 25  2022-04-01 00:00:00.000    179,956.34    -82,033.71      97,922.64
# 26  2022-03-01 00:00:00.000     57,874.04     -6,405.87      51,468.17
# 27  2022-02-01 00:00:00.000     67,512.87    -51,967.49      15,545.39
# 28  2022-01-01 00:00:00.000  1,093,722.20    -28,963.01   1,064,759.19
# 29  2021-12-01 00:00:00.000    369,319.29   -402,076.75     -32,757.46
# 30  2021-11-01 00:00:00.000 10,772,288.15    -44,398.56  10,727,889.58
# 31  2021-10-01 00:00:00.000    134,880.87   -246,875.05    -111,994.17
# 32  2021-09-01 00:00:00.000     49,792.03          0.00      49,792.03
# 33  2021-08-01 00:00:00.000    406,785.07     -1,074.11     405,710.96
# 34  2021-07-01 00:00:00.000          0.00          0.00           0.00

# %%
citydao_cf = citydao_cf[citydao_cf['MONTH'] > '2022-02-01']

# %%
citydao_cf['MONTH'] = pd.to_datetime(citydao_cf['MONTH'])
citydao_cf.set_index('MONTH',inplace=True)
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_48512\164232992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citydao_cf['MONTH'] = pd.to_datetime(citydao_cf['MONTH'])

# %%
citydao_cf.columns = [f'citydao_treasury_{col}' if col != 'MONTH' else col for col in citydao_cf.columns]

# %%
citydao_cf
# Out:
#             citydao_treasury_INFLOW  citydao_treasury_OUTFLOW  \
# MONTH
# 2024-05-01                     0.00                      0.00
# 2024-04-01                     0.03                 -1,503.02
# 2024-03-01                   149.52               -387,241.51
# 2024-02-01                   236.74                 -4,131.31
# 2024-01-01                   166.26                -20,628.66
# 2023-12-01                   275.96                 -6,027.33
# 2023-11-01                   232.06                    -70.52
# 2023-10-01                    56.15                -12,034.39
# 2023-09-01                27,972.02                 -1,614.21
# 2023-08-01                   105.24                 -9,024.91
# 2023-07-01                    83.45                 -1,560.16
# 2023-06-01                    13.19                 -7,293.96
# 2023-05-01                    65.54                 -9,510.93
# 2023-04-01                   189.24                 -1,651.02
# 2023-03-01                18,122.97                -83,193.00
# 2023-02-01                 1,342.22                -78,509.12
# 2023-01-01                 2,912.85                -48,900.00
# 2022-12-01                 3,810.05                 -7,060.09
# 2022-11-01               592,374.03               -507,629.07
# 2022-10-01                 1,158.15               -110,698.50
# 2022-09-01                 1,198.16               -377,805.00
# 2022-08-01               356,940.66               -203,003.62
# 2022-07-01               781,943.53               -854,404.14
# 2022-06-01               373,010.41             -2,633,917.81
# 2022-05-01               300,569.52               -172,743.96
# 2022-04-01               179,956.34                -82,033.71
# 2022-03-01                57,874.04                 -6,405.87
# 2022-02-01                67,512.87                -51,967.49
#
#             citydao_treasury_NET_CASH_FLOW
# MONTH
# 2024-05-01                            0.00
# 2024-04-01                       -1,502.99
# 2024-03-01                     -387,091.99
# 2024-02-01                       -3,894.57
# 2024-01-01                      -20,462.40
# 2023-12-01                       -5,751.37
# 2023-11-01                          161.54
# 2023-10-01                      -11,978.24
# 2023-09-01                       26,357.82
# 2023-08-01                       -8,919.67
# 2023-07-01                       -1,476.70
# 2023-06-01                       -7,280.77
# 2023-05-01                       -9,445.39
# 2023-04-01                       -1,461.78
# 2023-03-01                      -65,070.03
# 2023-02-01                      -77,166.90
# 2023-01-01                      -45,987.15
# 2022-12-01                       -3,250.04
# 2022-11-01                       84,744.96
# 2022-10-01                     -109,540.35
# 2022-09-01                     -376,606.84
# 2022-08-01                      153,937.05
# 2022-07-01                      -72,460.61
# 2022-06-01                   -2,260,907.40
# 2022-05-01                      127,825.56
# 2022-04-01                       97,922.64
# 2022-03-01                       51,468.17
# 2022-02-01                       15,545.39

# %%
citydao_burn_path = '../data/citydao_burnrate.csv'
citydao_burn = pd.read_csv(citydao_burn_path)

# %%
citydao_burn.dropna(inplace=True)

# %%
citydao_burn['MONTH'] = pd.to_datetime(citydao_burn['MONTH'])
citydao_burn.set_index('MONTH', inplace=True)

# %%
citydao_burn.columns = [f'citydao_treasury_{col}' if col != 'MONTH' else col for col in citydao_burn.columns]

# %%
cpi_path = '../data/sticky_price_consumer_price_index.csv'
cpi = pd.read_csv(cpi_path)

# %%
cpi['DATE'] = pd.to_datetime(cpi['DATE'])
cpi.set_index('DATE', inplace=True)

# %%
cpi.rename(columns={'CORESTICKM159SFRBATL':'sticky_cpi'}, inplace=True)

# %%
cpi.tail()
# Out:
#             sticky_cpi
# DATE
# 2023-10-01        4.88
# 2023-11-01        4.69
# 2023-12-01        4.55
# 2024-01-01        4.60
# 2024-02-01        4.40

# %%
ffr_path = '../data/effective_federal_funds_rate.csv'
ffr = pd.read_csv(ffr_path)
ffr['DATE'] = pd.to_datetime(ffr['DATE'])
ffr.set_index('DATE',inplace=True)

# %%
ffr['EFFR'] = pd.to_numeric(ffr['EFFR'], errors='coerce')

# %%
ffr['EFFR_DECIMAL'] = ffr['EFFR'] / 100

# %%
ffr.tail()
# Out:
#             EFFR  EFFR_DECIMAL
# DATE
# 2024-03-26  5.33          0.05
# 2024-03-27  5.33          0.05
# 2024-03-28  5.33          0.05
# 2024-03-29  5.33          0.05
# 2024-04-01  5.33          0.05

# %%
citydao_cf.tail()
# Out:
#             citydao_treasury_INFLOW  citydao_treasury_OUTFLOW  \
# MONTH
# 2022-06-01               373,010.41             -2,633,917.81
# 2022-05-01               300,569.52               -172,743.96
# 2022-04-01               179,956.34                -82,033.71
# 2022-03-01                57,874.04                 -6,405.87
# 2022-02-01                67,512.87                -51,967.49
#
#             citydao_treasury_NET_CASH_FLOW
# MONTH
# 2022-06-01                   -2,260,907.40
# 2022-05-01                      127,825.56
# 2022-04-01                       97,922.64
# 2022-03-01                       51,468.17
# 2022-02-01                       15,545.39

# %%
citydao_burn.tail()
# Out:
#             citydao_treasury_AVG_BALANCE  citydao_treasury_GROSS_BURN_RATE  \
# MONTH
# 2021-12-01                  7,547,994.04                        402,076.75
# 2021-11-01                  5,843,356.45                         44,398.56
# 2021-10-01                    256,797.80                        246,875.05
# 2021-09-01                    283,880.32                              0.00
# 2021-08-01                     90,434.88                          1,074.11
#
#             citydao_treasury_NET_BURN_RATE  citydao_treasury_TARGET_BURN_RATE  \
# MONTH
# 2021-12-01                      -32,757.46                         628,999.50
# 2021-11-01                   10,727,889.58                         486,946.37
# 2021-10-01                     -111,994.17                          21,399.82
# 2021-09-01                       49,792.03                          23,656.69
# 2021-08-01                      405,710.96                           7,536.24
#
#             citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO  \
# MONTH
# 2021-12-01                                           0.64
# 2021-11-01                                           0.09
# 2021-10-01                                          11.54
# 2021-09-01                                           0.00
# 2021-08-01                                           0.14
#
#             citydao_treasury_NET_BURN_RATE_HEALTH_RATIO
# MONTH
# 2021-12-01                                         0.05
# 2021-11-01                                        22.03
# 2021-10-01                                         5.23
# 2021-09-01                                         2.10
# 2021-08-01                                        53.83

# %%
dataset = pd.merge(citydao_burn, citydao_cf, left_index=True, right_index=True, how='right')

# %%
dataset.plot()
# Out:
# <Axes: xlabel='MONTH'>

# %%
dataset = dataset.resample('D').ffill()

# %%
dataset
# Out:
#             citydao_treasury_AVG_BALANCE  citydao_treasury_GROSS_BURN_RATE  \
# MONTH
# 2022-02-01                  6,355,731.85                         51,967.49
# 2022-02-02                  6,355,731.85                         51,967.49
# 2022-02-03                  6,355,731.85                         51,967.49
# 2022-02-04                  6,355,731.85                         51,967.49
# 2022-02-05                  6,355,731.85                         51,967.49
# ...                                  ...                               ...
# 2024-04-27                  2,795,269.37                          1,503.02
# 2024-04-28                  2,795,269.37                          1,503.02
# 2024-04-29                  2,795,269.37                          1,503.02
# 2024-04-30                  2,795,269.37                          1,503.02
# 2024-05-01                           NaN                               NaN
#
#             citydao_treasury_NET_BURN_RATE  citydao_treasury_TARGET_BURN_RATE  \
# MONTH
# 2022-02-01                       15,545.39                         529,644.32
# 2022-02-02                       15,545.39                         529,644.32
# 2022-02-03                       15,545.39                         529,644.32
# 2022-02-04                       15,545.39                         529,644.32
# 2022-02-05                       15,545.39                         529,644.32
# ...                                    ...                                ...
# 2024-04-27                       -1,502.99                         232,939.11
# 2024-04-28                       -1,502.99                         232,939.11
# 2024-04-29                       -1,502.99                         232,939.11
# 2024-04-30                       -1,502.99                         232,939.11
# 2024-05-01                             NaN                                NaN
#
#             citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO  \
# MONTH
# 2022-02-01                                           0.10
# 2022-02-02                                           0.10
# 2022-02-03                                           0.10
# 2022-02-04                                           0.10
# 2022-02-05                                           0.10
# ...                                                   ...
# 2024-04-27                                           0.01
# 2024-04-28                                           0.01
# 2024-04-29                                           0.01
# 2024-04-30                                           0.01
# 2024-05-01                                            NaN
#
#             citydao_treasury_NET_BURN_RATE_HEALTH_RATIO  \
# MONTH
# 2022-02-01                                         0.03
# 2022-02-02                                         0.03
# 2022-02-03                                         0.03
# 2022-02-04                                         0.03
# 2022-02-05                                         0.03
# ...                                                 ...
# 2024-04-27                                         0.01
# 2024-04-28                                         0.01
# 2024-04-29                                         0.01
# 2024-04-30                                         0.01
# 2024-05-01                                          NaN
#
#             citydao_treasury_INFLOW  citydao_treasury_OUTFLOW  \
# MONTH
# 2022-02-01                67,512.87                -51,967.49
# 2022-02-02                67,512.87                -51,967.49
# 2022-02-03                67,512.87                -51,967.49
# 2022-02-04                67,512.87                -51,967.49
# 2022-02-05                67,512.87                -51,967.49
# ...                             ...                       ...
# 2024-04-27                     0.03                 -1,503.02
# 2024-04-28                     0.03                 -1,503.02
# 2024-04-29                     0.03                 -1,503.02
# 2024-04-30                     0.03                 -1,503.02
# 2024-05-01                     0.00                      0.00
#
#             citydao_treasury_NET_CASH_FLOW
# MONTH
# 2022-02-01                       15,545.39
# 2022-02-02                       15,545.39
# 2022-02-03                       15,545.39
# 2022-02-04                       15,545.39
# 2022-02-05                       15,545.39
# ...                                    ...
# 2024-04-27                       -1,502.99
# 2024-04-28                       -1,502.99
# 2024-04-29                       -1,502.99
# 2024-04-30                       -1,502.99
# 2024-05-01                            0.00
#
# [821 rows x 9 columns]

# %%
citydao_df['DAY'] = pd.to_datetime(citydao_df['DAY'])
citydao_df.set_index('DAY',inplace=True)

# %%
citydao_data = pd.merge(dataset,citydao_df, left_index=True, right_index=True)

# %%
citydao_data.columns
# Out:
# Index(['citydao_treasury_AVG_BALANCE', 'citydao_treasury_GROSS_BURN_RATE',
#        'citydao_treasury_NET_BURN_RATE', 'citydao_treasury_TARGET_BURN_RATE',
#        'citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO',
#        'citydao_treasury_NET_BURN_RATE_HEALTH_RATIO',
#        'citydao_treasury_INFLOW', 'citydao_treasury_OUTFLOW',
#        'citydao_treasury_NET_CASH_FLOW', 'DAILY_PRICE_BACON',
#        'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV', 'DAILY_PRICE_TOKEN',
#        'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH',
#        'citydao_treasury_FILLED_BALANCE_BACON',
#        'citydao_treasury_FILLED_BALANCE_ETH',
#        'citydao_treasury_FILLED_BALANCE_MTV',
#        'citydao_treasury_FILLED_BALANCE_TOKEN',
#        'citydao_treasury_FILLED_BALANCE_USDC',
#        'citydao_treasury_FILLED_BALANCE_WETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_BACON',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_ETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_MTV',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_USDC',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_WETH',
#        'citydao_treasury_COMPOSITION_BACON',
#        'citydao_treasury_COMPOSITION_ETH', 'citydao_treasury_COMPOSITION_MTV',
#        'citydao_treasury_COMPOSITION_TOKEN',
#        'citydao_treasury_COMPOSITION_USDC',
#        'citydao_treasury_COMPOSITION_WETH',
#        'citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN',
#        'citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN',
#        'citydao_treasury_ROLLING_AVG_30D',
#        'citydao_treasury_ROLLING_STDDEV_30D',
#        'citydao_treasury_ROLLING_AVG_90D',
#        'citydao_treasury_ROLLING_STDDEV_90D', 'TB3MS',
#        'citydao_treasury_SHARPE_RATIO_CUM',
#        'citydao_treasury_SHARPE_RATIO_30D',
#        'citydao_treasury_SHARPE_RATIO_90D',
#        'citydao_treasury_TREASURY_RETURN'],
#       dtype='object')

# %%
citydao_data
# Out:
#             citydao_treasury_AVG_BALANCE  citydao_treasury_GROSS_BURN_RATE  \
# 2022-02-01                  6,355,731.85                         51,967.49
# 2022-02-02                  6,355,731.85                         51,967.49
# 2022-02-03                  6,355,731.85                         51,967.49
# 2022-02-04                  6,355,731.85                         51,967.49
# 2022-02-05                  6,355,731.85                         51,967.49
# ...                                  ...                               ...
# 2024-03-28                  3,233,439.20                        387,241.51
# 2024-03-29                  3,233,439.20                        387,241.51
# 2024-03-30                  3,233,439.20                        387,241.51
# 2024-03-31                  3,233,439.20                        387,241.51
# 2024-04-01                  2,795,269.37                          1,503.02
#
#             citydao_treasury_NET_BURN_RATE  citydao_treasury_TARGET_BURN_RATE  \
# 2022-02-01                       15,545.39                         529,644.32
# 2022-02-02                       15,545.39                         529,644.32
# 2022-02-03                       15,545.39                         529,644.32
# 2022-02-04                       15,545.39                         529,644.32
# 2022-02-05                       15,545.39                         529,644.32
# ...                                    ...                                ...
# 2024-03-28                     -387,091.99                         269,453.27
# 2024-03-29                     -387,091.99                         269,453.27
# 2024-03-30                     -387,091.99                         269,453.27
# 2024-03-31                     -387,091.99                         269,453.27
# 2024-04-01                       -1,502.99                         232,939.11
#
#             citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO  \
# 2022-02-01                                           0.10
# 2022-02-02                                           0.10
# 2022-02-03                                           0.10
# 2022-02-04                                           0.10
# 2022-02-05                                           0.10
# ...                                                   ...
# 2024-03-28                                           1.44
# 2024-03-29                                           1.44
# 2024-03-30                                           1.44
# 2024-03-31                                           1.44
# 2024-04-01                                           0.01
#
#             citydao_treasury_NET_BURN_RATE_HEALTH_RATIO  \
# 2022-02-01                                         0.03
# 2022-02-02                                         0.03
# 2022-02-03                                         0.03
# 2022-02-04                                         0.03
# 2022-02-05                                         0.03
# ...                                                 ...
# 2024-03-28                                         1.44
# 2024-03-29                                         1.44
# 2024-03-30                                         1.44
# 2024-03-31                                         1.44
# 2024-04-01                                         0.01
#
#             citydao_treasury_INFLOW  citydao_treasury_OUTFLOW  \
# 2022-02-01                67,512.87                -51,967.49
# 2022-02-02                67,512.87                -51,967.49
# 2022-02-03                67,512.87                -51,967.49
# 2022-02-04                67,512.87                -51,967.49
# 2022-02-05                67,512.87                -51,967.49
# ...                             ...                       ...
# 2024-03-28                   149.52               -387,241.51
# 2024-03-29                   149.52               -387,241.51
# 2024-03-30                   149.52               -387,241.51
# 2024-03-31                   149.52               -387,241.51
# 2024-04-01                     0.03                 -1,503.02
#
#             citydao_treasury_NET_CASH_FLOW  DAILY_PRICE_BACON  ...  \
# 2022-02-01                       15,545.39               0.01  ...
# 2022-02-02                       15,545.39               0.01  ...
# 2022-02-03                       15,545.39               0.01  ...
# 2022-02-04                       15,545.39               0.01  ...
# 2022-02-05                       15,545.39               0.01  ...
# ...                                    ...                ...  ...
# 2024-03-28                     -387,091.99               0.00  ...
# 2024-03-29                     -387,091.99               0.00  ...
# 2024-03-30                     -387,091.99               0.00  ...
# 2024-03-31                     -387,091.99               0.00  ...
# 2024-04-01                       -1,502.99               0.00  ...
#
#             citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN  \
# 2022-02-01                                              0.03
# 2022-02-02                                              0.04
# 2022-02-03                                              0.03
# 2022-02-04                                              0.06
# 2022-02-05                                              0.05
# ...                                                      ...
# 2024-03-28                                              0.03
# 2024-03-29                                              0.03
# 2024-03-30                                              0.03
# 2024-03-31                                              0.03
# 2024-04-01                                              0.03
#
#             citydao_treasury_ROLLING_AVG_30D  \
# 2022-02-01                              0.02
# 2022-02-02                             -0.00
# 2022-02-03                             -0.00
# 2022-02-04                              0.02
# 2022-02-05                              0.02
# ...                                      ...
# 2024-03-28                              0.00
# 2024-03-29                              0.00
# 2024-03-30                              0.00
# 2024-03-31                              0.00
# 2024-04-01                              0.00
#
#             citydao_treasury_ROLLING_STDDEV_30D  \
# 2022-02-01                                 0.03
# 2022-02-02                                 0.04
# 2022-02-03                                 0.03
# 2022-02-04                                 0.06
# 2022-02-05                                 0.05
# ...                                         ...
# 2024-03-28                                 0.03
# 2024-03-29                                 0.03
# 2024-03-30                                 0.03
# 2024-03-31                                 0.03
# 2024-04-01                                 0.03
#
#             citydao_treasury_ROLLING_AVG_90D  \
# 2022-02-01                              0.02
# 2022-02-02                             -0.00
# 2022-02-03                             -0.00
# 2022-02-04                              0.02
# 2022-02-05                              0.02
# ...                                      ...
# 2024-03-28                              0.00
# 2024-03-29                              0.00
# 2024-03-30                              0.00
# 2024-03-31                              0.00
# 2024-04-01                              0.00
#
#             citydao_treasury_ROLLING_STDDEV_90D  TB3MS  \
# 2022-02-01                                 0.03   0.00
# 2022-02-02                                 0.04   0.00
# 2022-02-03                                 0.03   0.00
# 2022-02-04                                 0.06   0.00
# 2022-02-05                                 0.05   0.00
# ...                                         ...    ...
# 2024-03-28                                 0.02   0.05
# 2024-03-29                                 0.02   0.05
# 2024-03-30                                 0.02   0.05
# 2024-03-31                                 0.02   0.05
# 2024-04-01                                 0.02   0.05
#
#             citydao_treasury_SHARPE_RATIO_CUM  \
# 2022-02-01                               0.03
# 2022-02-02                              -0.01
# 2022-02-03                              -0.01
# 2022-02-04                               0.02
# 2022-02-05                               0.02
# ...                                       ...
# 2024-03-28                              -0.11
# 2024-03-29                              -0.11
# 2024-03-30                              -0.11
# 2024-03-31                              -0.11
# 2024-04-01                              -0.11
#
#             citydao_treasury_SHARPE_RATIO_30D  \
# 2022-02-01                               0.03
# 2022-02-02                              -0.01
# 2022-02-03                              -0.01
# 2022-02-04                               0.02
# 2022-02-05                               0.02
# ...                                       ...
# 2024-03-28                              -0.08
# 2024-03-29                              -0.08
# 2024-03-30                              -0.08
# 2024-03-31                              -0.08
# 2024-04-01                              -0.08
#
#             citydao_treasury_SHARPE_RATIO_90D  \
# 2022-02-01                               0.03
# 2022-02-02                              -0.01
# 2022-02-03                              -0.01
# 2022-02-04                               0.02
# 2022-02-05                               0.02
# ...                                       ...
# 2024-03-28                              -0.11
# 2024-03-29                              -0.11
# 2024-03-30                              -0.11
# 2024-03-31                              -0.11
# 2024-04-01                              -0.11
#
#             citydao_treasury_TREASURY_RETURN
# 2022-02-01                            100.00
# 2022-02-02                             96.13
# 2022-02-03                             95.74
# 2022-02-04                            106.14
# 2022-02-05                            107.27
# ...                                      ...
# 2024-03-28                            108.15
# 2024-03-29                            106.84
# 2024-03-30                            106.49
# 2024-03-31                            109.85
# 2024-04-01                            106.59
#
# [791 rows x 44 columns]

# %%
macro_data = pd.merge(ffr,cpi, left_index=True, right_index=True )

# %%
macro_data[['EFFR','EFFR_DECIMAL']] = macro_data[['EFFR','EFFR_DECIMAL']].ffill()

# %%
macro_data.head()
# Out:
#             EFFR  EFFR_DECIMAL  sticky_cpi
# DATE
# 2019-11-01  1.57          0.02        2.77
# 2020-01-01  1.57          0.02        2.79
# 2020-04-01  0.06          0.00        2.18
# 2020-05-01  0.05          0.00        2.01
# 2020-06-01  0.05          0.00        1.99

# %%
macro_data = macro_data.resample('D').ffill()

# %%
#macro_data = macro_data.merge(tbill_daily, left_index=True, right_index=True,how='left' )

# %%
macro_data
# Out:
#             EFFR  EFFR_DECIMAL  sticky_cpi
# DATE
# 2019-11-01  1.57          0.02        2.77
# 2019-11-02  1.57          0.02        2.77
# 2019-11-03  1.57          0.02        2.77
# 2019-11-04  1.57          0.02        2.77
# 2019-11-05  1.57          0.02        2.77
# ...          ...           ...         ...
# 2024-01-28  5.33          0.05        4.60
# 2024-01-29  5.33          0.05        4.60
# 2024-01-30  5.33          0.05        4.60
# 2024-01-31  5.33          0.05        4.60
# 2024-02-01  5.33          0.05        4.40
#
# [1554 rows x 3 columns]

# %%
comprehensive_data = pd.merge(macro_data,citydao_data, left_index=True, right_index=True, how='right' )

# %%
comprehensive_data[['EFFR','EFFR_DECIMAL','sticky_cpi']] = comprehensive_data[['EFFR','EFFR_DECIMAL','sticky_cpi']].ffill()

# %%
print(list(comprehensive_data.head()))
# Out:
# ['EFFR', 'EFFR_DECIMAL', 'sticky_cpi', 'citydao_treasury_AVG_BALANCE', 'citydao_treasury_GROSS_BURN_RATE', 'citydao_treasury_NET_BURN_RATE', 'citydao_treasury_TARGET_BURN_RATE', 'citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO', 'citydao_treasury_NET_BURN_RATE_HEALTH_RATIO', 'citydao_treasury_INFLOW', 'citydao_treasury_OUTFLOW', 'citydao_treasury_NET_CASH_FLOW', 'DAILY_PRICE_BACON', 'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV', 'DAILY_PRICE_TOKEN', 'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH', 'citydao_treasury_FILLED_BALANCE_BACON', 'citydao_treasury_FILLED_BALANCE_ETH', 'citydao_treasury_FILLED_BALANCE_MTV', 'citydao_treasury_FILLED_BALANCE_TOKEN', 'citydao_treasury_FILLED_BALANCE_USDC', 'citydao_treasury_FILLED_BALANCE_WETH', 'citydao_treasury_TOTAL_VALUE_IN_USD_BACON', 'citydao_treasury_TOTAL_VALUE_IN_USD_ETH', 'citydao_treasury_TOTAL_VALUE_IN_USD_MTV', 'citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN', 'citydao_treasury_TOTAL_VALUE_IN_USD_USDC', 'citydao_treasury_TOTAL_VALUE_IN_USD_WETH', 'citydao_treasury_COMPOSITION_BACON', 'citydao_treasury_COMPOSITION_ETH', 'citydao_treasury_COMPOSITION_MTV', 'citydao_treasury_COMPOSITION_TOKEN', 'citydao_treasury_COMPOSITION_USDC', 'citydao_treasury_COMPOSITION_WETH', 'citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN', 'citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN', 'citydao_treasury_ROLLING_AVG_30D', 'citydao_treasury_ROLLING_STDDEV_30D', 'citydao_treasury_ROLLING_AVG_90D', 'citydao_treasury_ROLLING_STDDEV_90D', 'TB3MS', 'citydao_treasury_SHARPE_RATIO_CUM', 'citydao_treasury_SHARPE_RATIO_30D', 'citydao_treasury_SHARPE_RATIO_90D', 'citydao_treasury_TREASURY_RETURN']

# %%
comprehensive_data.columns
# Out:
# Index(['EFFR', 'EFFR_DECIMAL', 'sticky_cpi', 'citydao_treasury_AVG_BALANCE',
#        'citydao_treasury_GROSS_BURN_RATE', 'citydao_treasury_NET_BURN_RATE',
#        'citydao_treasury_TARGET_BURN_RATE',
#        'citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO',
#        'citydao_treasury_NET_BURN_RATE_HEALTH_RATIO',
#        'citydao_treasury_INFLOW', 'citydao_treasury_OUTFLOW',
#        'citydao_treasury_NET_CASH_FLOW', 'DAILY_PRICE_BACON',
#        'DAILY_PRICE_ETH', 'DAILY_PRICE_MTV', 'DAILY_PRICE_TOKEN',
#        'DAILY_PRICE_USDC', 'DAILY_PRICE_WETH',
#        'citydao_treasury_FILLED_BALANCE_BACON',
#        'citydao_treasury_FILLED_BALANCE_ETH',
#        'citydao_treasury_FILLED_BALANCE_MTV',
#        'citydao_treasury_FILLED_BALANCE_TOKEN',
#        'citydao_treasury_FILLED_BALANCE_USDC',
#        'citydao_treasury_FILLED_BALANCE_WETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_BACON',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_ETH',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_MTV',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_USDC',
#        'citydao_treasury_TOTAL_VALUE_IN_USD_WETH',
#        'citydao_treasury_COMPOSITION_BACON',
#        'citydao_treasury_COMPOSITION_ETH', 'citydao_treasury_COMPOSITION_MTV',
#        'citydao_treasury_COMPOSITION_TOKEN',
#        'citydao_treasury_COMPOSITION_USDC',
#        'citydao_treasury_COMPOSITION_WETH',
#        'citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN',
#        'citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN',
#        'citydao_treasury_ROLLING_AVG_30D',
#        'citydao_treasury_ROLLING_STDDEV_30D',
#        'citydao_treasury_ROLLING_AVG_90D',
#        'citydao_treasury_ROLLING_STDDEV_90D', 'TB3MS',
#        'citydao_treasury_SHARPE_RATIO_CUM',
#        'citydao_treasury_SHARPE_RATIO_30D',
#        'citydao_treasury_SHARPE_RATIO_90D',
#        'citydao_treasury_TREASURY_RETURN'],
#       dtype='object')

# %%
comprehensive_data[['citydao_treasury_NET_CASH_FLOW','citydao_treasury_NET_BURN_RATE']]
# Out:
#             citydao_treasury_NET_CASH_FLOW  citydao_treasury_NET_BURN_RATE
# 2022-02-01                       15,545.39                       15,545.39
# 2022-02-02                       15,545.39                       15,545.39
# 2022-02-03                       15,545.39                       15,545.39
# 2022-02-04                       15,545.39                       15,545.39
# 2022-02-05                       15,545.39                       15,545.39
# ...                                    ...                             ...
# 2024-03-28                     -387,091.99                     -387,091.99
# 2024-03-29                     -387,091.99                     -387,091.99
# 2024-03-30                     -387,091.99                     -387,091.99
# 2024-03-31                     -387,091.99                     -387,091.99
# 2024-04-01                       -1,502.99                       -1,502.99
#
# [791 rows x 2 columns]

# %%
comprehensive_data.isna().sum()
# Out:
# EFFR                                                0
# EFFR_DECIMAL                                        0
# sticky_cpi                                          0
# citydao_treasury_AVG_BALANCE                        0
# citydao_treasury_GROSS_BURN_RATE                    0
# citydao_treasury_NET_BURN_RATE                      0
# citydao_treasury_TARGET_BURN_RATE                   0
# citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO       0
# citydao_treasury_NET_BURN_RATE_HEALTH_RATIO         0
# citydao_treasury_INFLOW                             0
# citydao_treasury_OUTFLOW                            0
# citydao_treasury_NET_CASH_FLOW                      0
# DAILY_PRICE_BACON                                   0
# DAILY_PRICE_ETH                                     0
# DAILY_PRICE_MTV                                     0
# DAILY_PRICE_TOKEN                                   0
# DAILY_PRICE_USDC                                    0
# DAILY_PRICE_WETH                                    0
# citydao_treasury_FILLED_BALANCE_BACON               0
# citydao_treasury_FILLED_BALANCE_ETH                 0
# citydao_treasury_FILLED_BALANCE_MTV                 0
# citydao_treasury_FILLED_BALANCE_TOKEN               0
# citydao_treasury_FILLED_BALANCE_USDC                0
# citydao_treasury_FILLED_BALANCE_WETH                0
# citydao_treasury_TOTAL_VALUE_IN_USD_BACON           0
# citydao_treasury_TOTAL_VALUE_IN_USD_ETH             0
# citydao_treasury_TOTAL_VALUE_IN_USD_MTV             0
# citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN           0
# citydao_treasury_TOTAL_VALUE_IN_USD_USDC            0
# citydao_treasury_TOTAL_VALUE_IN_USD_WETH            0
# citydao_treasury_COMPOSITION_BACON                  0
# citydao_treasury_COMPOSITION_ETH                    0
# citydao_treasury_COMPOSITION_MTV                    0
# citydao_treasury_COMPOSITION_TOKEN                  0
# citydao_treasury_COMPOSITION_USDC                   0
# citydao_treasury_COMPOSITION_WETH                   0
# citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN       0
# citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN    0
# citydao_treasury_ROLLING_AVG_30D                    0
# citydao_treasury_ROLLING_STDDEV_30D                 0
# citydao_treasury_ROLLING_AVG_90D                    0
# citydao_treasury_ROLLING_STDDEV_90D                 0
# TB3MS                                               0
# citydao_treasury_SHARPE_RATIO_CUM                   0
# citydao_treasury_SHARPE_RATIO_30D                   0
# citydao_treasury_SHARPE_RATIO_90D                   0
# citydao_treasury_TREASURY_RETURN                    0
# dtype: int64

# %%
correlations = comprehensive_data.corr()

# Select correlations of all features with the target variable, excluding the target variable itself
return_target_correlations = correlations['citydao_treasury_TREASURY_RETURN'].drop('citydao_treasury_TREASURY_RETURN')

# Sort the correlations to see the most positive and negative correlations at the top and bottom, respectively
return_sorted_correlations = return_target_correlations.sort_values(ascending=False)

# Display the sorted correlations
print(return_sorted_correlations)
# Out:
# DAILY_PRICE_ETH                                     0.98
# DAILY_PRICE_WETH                                    0.98
# citydao_treasury_TARGET_BURN_RATE                   0.73
# citydao_treasury_AVG_BALANCE                        0.73
# DAILY_PRICE_MTV                                     0.71
# citydao_treasury_CUM_ROLLING_AVG_DAILY_RETURN       0.67
# citydao_treasury_TOTAL_VALUE_IN_USD_ETH             0.67
# citydao_treasury_ROLLING_AVG_90D                    0.60
# citydao_treasury_FILLED_BALANCE_ETH                 0.58
# citydao_treasury_COMPOSITION_ETH                    0.58
# citydao_treasury_TOTAL_VALUE_IN_USD_BACON           0.49
# DAILY_PRICE_BACON                                   0.49
# citydao_treasury_TOTAL_VALUE_IN_USD_TOKEN           0.44
# DAILY_PRICE_TOKEN                                   0.43
# citydao_treasury_COMPOSITION_TOKEN                  0.43
# citydao_treasury_FILLED_BALANCE_TOKEN               0.42
# citydao_treasury_ROLLING_AVG_30D                    0.40
# citydao_treasury_TOTAL_VALUE_IN_USD_MTV             0.35
# citydao_treasury_COMPOSITION_MTV                    0.28
# citydao_treasury_SHARPE_RATIO_30D                   0.28
# citydao_treasury_OUTFLOW                            0.28
# citydao_treasury_FILLED_BALANCE_MTV                 0.24
# citydao_treasury_SHARPE_RATIO_90D                   0.21
# citydao_treasury_NET_BURN_RATE                      0.20
# citydao_treasury_NET_CASH_FLOW                      0.20
# citydao_treasury_COMPOSITION_BACON                  0.16
# citydao_treasury_SHARPE_RATIO_CUM                   0.15
# citydao_treasury_ROLLING_STDDEV_30D                 0.12
# citydao_treasury_ROLLING_STDDEV_90D                 0.09
# DAILY_PRICE_USDC                                    0.01
# EFFR_DECIMAL                                       -0.17
# EFFR                                               -0.17
# citydao_treasury_CUM_ROLLING_STDDEV_DAILY_RETURN   -0.21
# citydao_treasury_NET_BURN_RATE_HEALTH_RATIO        -0.21
# citydao_treasury_INFLOW                            -0.27
# citydao_treasury_TOTAL_VALUE_IN_USD_WETH           -0.27
# citydao_treasury_GROSS_BURN_RATE                   -0.28
# TB3MS                                              -0.28
# citydao_treasury_GROSS_BURN_RATE_HEALTH_RATIO      -0.32
# citydao_treasury_TOTAL_VALUE_IN_USD_USDC           -0.42
# citydao_treasury_FILLED_BALANCE_USDC               -0.42
# citydao_treasury_COMPOSITION_WETH                  -0.43
# citydao_treasury_COMPOSITION_USDC                  -0.60
# citydao_treasury_FILLED_BALANCE_WETH               -0.67
# sticky_cpi                                         -0.72
# citydao_treasury_FILLED_BALANCE_BACON                NaN
# Name: citydao_treasury_TREASURY_RETURN, dtype: float64
